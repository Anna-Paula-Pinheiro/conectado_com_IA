# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Paula-Pinheiro/conectado_com_IA/blob/main/Conectado_com_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Rodando IA no Google Colab

# %%
import os
from google.colab import userdata
os.environ ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model="gemini-2.5-flash", contents= "O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas e máquinas que podem realizar tarefas que, historicamente, exigiriam inteligência humana. Em essência, a IA busca simular e automatizar processos cognitivos humanos, como aprender, raciocinar, resolver problemas, perceber, compreender a linguagem e tomar decisões.
#
# ### Componentes Chave e Capacidades da IA:
#
# 1.  **Aprendizado de Máquina (Machine Learning - ML):** É o principal motor da IA moderna. Permite que os sistemas aprendam a partir de dados, identifiquem padrões e tomem decisões com mínima intervenção humana. Existem vários tipos:
#     *   **Aprendizado Supervisionado:** Treinar um modelo com dados rotulados (ex: fotos de cães e gatos com suas identificações).
#     *   **Aprendizado Não Supervisionado:** Encontrar padrões e estruturas em dados não rotulados (ex: agrupamento de clientes por comportamento de compra).
# ...

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
resposta = chat.send_message("Quando foi lançado o chat GPT?")

# %%
print(resposta.text)
# Out:
# O **ChatGPT** foi lançado ao público como um protótipo pela OpenAI em **30 de novembro de 2022**.
#
# Foi um lançamento que gerou um enorme impacto e ganhou popularidade rapidamente, atingindo 1 milhão de usuários em poucos dias, devido à sua capacidade de gerar textos coerentes e contextuais em diversas tarefas. Ele é baseado na arquitetura GPT-3.5 (na sua versão inicial) e marcou um ponto de virada na percepção pública sobre o potencial da IA generativa.

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é a Inteligência Artificial?'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""A **Inteligência Artificial (IA)** é um campo da ciência da computação que se dedica a criar sistemas ou máquinas capazes de simular a inteligência humana. O objetivo é que esses sistemas possam realizar tarefas que, normalmente, exigiriam o pensamento e a capacidade cognitiva de um ser humano.
#
#  **Em termos mais simples, a IA busca fazer com que computadores e máquinas possam:**
#
#  1.  **Aprender:** Adquirir conhecimento e habilidades a partir de dados e experiências, sem serem explicitamente programados para cada cenário.
#  2.  **Raciocinar:** Processar informações, tirar conclusões lógicas e tomar decisões.
#  3.  **Resolver Problemas:** Encontrar soluções para desafios complexos.
#  4.  **Perceber:** Interpretar informações sensoriais (como imagens, sons, fala) e entender o ambiente.
# ...

# %%
prompt = input("Digite sua pergunta: ")
while prompt != "fim":
  resposta = chat.send_message(prompt)
  print(resposta.text)
  print("\n")
  prompt = input("Digite sua pergunta: ")
# Out:
# Digite sua pergunta: O que é IA? Responda Sucintamente
# **Inteligência Artificial (IA)** é o campo da computação que permite a máquinas **simular a inteligência humana** para aprender, raciocinar, perceber e resolver problemas.
#
#
# Digite sua pergunta: Quando foi lançado o chat GPT?
# O ChatGPT foi lançado em **30 de novembro de 2022**.
#
#
# Digite sua pergunta: Quem foi Turing?
# **Alan Turing** foi um matemático, lógico e cientista da computação britânico, amplamente considerado o **pai da ciência da computação teórica e da inteligência artificial**.
#
# Ele é famoso por:
# *   Propor a **Máquina de Turing**, o modelo teórico para todos os computadores.
# *   Ter um papel crucial na decifração do código alemão **Enigma** durante a Segunda Guerra Mundial.
# *   Criar o **Teste de Turing**, um critério para avaliar a inteligência de uma máquina.
#
# Sua vida terminou tragicamente devido à perseguição por sua homossexualidade.
#
#
# Digite sua pergunta: fim
